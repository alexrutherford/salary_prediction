# %%
import pandas as pd

# %%
import openpyxl

# %% [markdown]
# ## Salary Data

# %%
# !unzip ../data/raw/oesm21nat.zip
# Out:
# Archive:  ../data/raw/oesm21nat.zip
#   inflating: oesm21nat/national_M2021_dl.xlsx

# %%
# !mv oesm21nat/ ../data/interim/

# %%
salaryDf = pd.read_excel('../data/interim/oesm21nat/national_M2021_dl.xlsx')

# %%
salaryDf.head()
# Out:
#    AREA AREA_TITLE  AREA_TYPE PRIM_STATE  NAICS     NAICS_TITLE  \
# 0    99       U.S.          1         US      0  Cross-industry
# 1    99       U.S.          1         US      0  Cross-industry
# 2    99       U.S.          1         US      0  Cross-industry
# 3    99       U.S.          1         US      0  Cross-industry
# 4    99       U.S.          1         US      0  Cross-industry
#
#           I_GROUP  OWN_CODE OCC_CODE               OCC_TITLE  ... H_MEDIAN  \
# 0  cross-industry      1235  00-0000         All Occupations  ...       22
# 1  cross-industry      1235  11-0000  Management Occupations  ...    49.25
# 2  cross-industry      1235  11-1000          Top Executives  ...    47.46
# 3  cross-industry      1235  11-1010        Chief Executives  ...    86.31
# 4  cross-industry      1235  11-1011        Chief Executives  ...    86.31
#
#    H_PCT75  H_PCT90  A_PCT10  A_PCT25  A_MEDIAN  A_PCT75 A_PCT90 ANNUAL HOURLY
# ...

# %%
salaryDf.groupby('O_GROUP').first()
# Out:
#           AREA AREA_TITLE  AREA_TYPE PRIM_STATE  NAICS     NAICS_TITLE  \
# O_GROUP
# broad       99       U.S.          1         US      0  Cross-industry
# detailed    99       U.S.          1         US      0  Cross-industry
# major       99       U.S.          1         US      0  Cross-industry
# minor       99       U.S.          1         US      0  Cross-industry
# total       99       U.S.          1         US      0  Cross-industry
#
#                  I_GROUP  OWN_CODE OCC_CODE               OCC_TITLE  ...  \
# O_GROUP                                                              ...
# broad     cross-industry      1235  11-1010        Chief Executives  ...
# detailed  cross-industry      1235  11-1011        Chief Executives  ...
# major     cross-industry      1235  11-0000  Management Occupations  ...
# minor     cross-industry      1235  11-1000          Top Executives  ...
# total     cross-industry      1235  00-0000         All Occupations  ...
#
# ...

# %%
salaryDf.columns
# Out:
# Index(['AREA', 'AREA_TITLE', 'AREA_TYPE', 'PRIM_STATE', 'NAICS', 'NAICS_TITLE',
#        'I_GROUP', 'OWN_CODE', 'OCC_CODE', 'OCC_TITLE', 'O_GROUP', 'TOT_EMP',
#        'EMP_PRSE', 'JOBS_1000', 'LOC_QUOTIENT', 'PCT_TOTAL', 'PCT_RPT',
#        'H_MEAN', 'A_MEAN', 'MEAN_PRSE', 'H_PCT10', 'H_PCT25', 'H_MEDIAN',
#        'H_PCT75', 'H_PCT90', 'A_PCT10', 'A_PCT25', 'A_MEDIAN', 'A_PCT75',
#        'A_PCT90', 'ANNUAL', 'HOURLY'],
#       dtype='object')

# %%
salaryDf[salaryDf.O_GROUP == 'detailed']['OCC_TITLE'].value_counts()
# Out:
# Chief Executives                                      1
# Farmworkers, Farm, Ranch, and Aquacultural Animals    1
# Office Machine Operators, Except Computer             1
# Proofreaders and Copy Markers                         1
# Statistical Assistants                                1
#                                                      ..
# Coaches and Scouts                                    1
# Umpires, Referees, and Other Sports Officials         1
# Dancers                                               1
# Choreographers                                        1
# Material Moving Workers, All Other                    1
# Name: OCC_TITLE, Length: 831, dtype: int64

# %%
salaryDf[salaryDf.O_GROUP == 'detailed']['A_MEAN'].isna()
# All jobs have an annual salary
# Out:
# 4       False
# 6       False
# 8       False
# 11      False
# 13      False
#         ...
# 1395    False
# 1396    False
# 1398    False
# 1400    False
# 1402    False
# Name: A_MEAN, Length: 831, dtype: bool

# %%
salaryDf[salaryDf.O_GROUP == 'detailed'][['OCC_TITLisnullOCC_CODE','A_MEAN']].to_csv('../data/processed/salary.csv')

# %% [markdown]
# ## Job Description Data

# %%
jobDf = pd.read_csv('../data/raw/Occupation_Data.txt',sep = '\t')

# %%
jobDf.head()
# Out:
#   O*NET-SOC Code                                Title  \
# 0     11-1011.00                     Chief Executives
# 1     11-1011.03        Chief Sustainability Officers
# 2     11-1021.00      General and Operations Managers
# 3     11-1031.00                          Legislators
# 4     11-2011.00  Advertising and Promotions Managers
#
#                                          Description
# 0  Determine and formulate policies and provide o...
# 1  Communicate and coordinate with management, sh...
# 2  Plan, direct, or coordinate the operations of ...
# 3  Develop, introduce, or enact laws and statutes...
# 4  Plan, direct, or coordinate advertising polici...

# %%
# !cp ../data/raw/Occupation_Data.txt ../data/processed/occupations.csv
